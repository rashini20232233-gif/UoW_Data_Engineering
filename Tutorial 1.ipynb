# %%
print("Welcome to Data Engineering Module!")
# Out:
# Welcome to Data Engineering Module!

# %%
age = 25 				#int
pi = 3.14				#float
name = "Habeeb"			#str
is_student = True			#bool

# %%
print(f"Welcome to Data Engineering Module, my name is {name}, I am the Module leader, and I am {age} years old.")
# Out:
# Welcome to Data Engineering Module, my name is Habeeb, I am the Module leader, and I am 25 years old.

# %%
a = 10
b = 3
print(a + b, a ** b, a // b)
# Out:
# 13 1000 3

# %%
#String indexing and slicing.
#Common methods: .lower(), .upper(), .replace(), .split().
text = "Data Engineering"
print(text.lower())
print(text[0:4])   # first word
print(text[::-1]) # reverse string through slicing
# Out:
# data engineering
# Data
# gnireenignE ataD

# %%
import sys
print(sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
print("Welcome to Data Engineering Module, my name is {name}, I am the Module leader, and I am {age} years old.")
# Out:
# Welcome to Data Engineering Module, my name is {name}, I am the Module leader, and I am {age} years old.

# %%
print("Welcome to Data Engineering Module, my name is {name}, I am the Module leader, and I am {age} years old.")
# Out:
# Welcome to Data Engineering Module, my name is {name}, I am the Module leader, and I am {age} years old.

# %%
# Lists
fruits = ["apple", "banana", "cherry"]
print(fruits)
print(fruits[0]) # indexing
fruits.append("date") # add new item
print(fruits)

# Tuples (immutable sequences)
coordinates = (10.5, 20.3)
print(coordinates)

# Dictionaries (key-value pairs)
student = {"name": "Alice", "age": 25, "course": "Data Engineering"}
print(student["name"])
print(student.get("course"))

# Sets (unique, unordered collection)
unique_numbers = {1, 2, 2, 3, 4}
print(unique_numbers)
# Out:
# ['apple', 'banana', 'cherry']
# apple
# ['apple', 'banana', 'cherry', 'date']
# (10.5, 20.3)
# Alice
# Data Engineering
# {1, 2, 3, 4}

# %%
module_name="Data Engineering"

# %%
module_name[5]
# Out:
# 'E'

# %%
module_name[1:6]
# Out:
# 'ata E'

# %%
module_name[1:6:2]
# Out:
# 'aaE'

# %%
module_name[6:3:-1]
# Out:
# 'nE '

# %%
try:
    import pandas as pd
    print("pandas is already installed.")
except ImportError:
    print("pandas is not installed.")
# Out:
# pandas is already installed.

# %%
module_name="Data Engineering"

# %%
new_module_name = module_name.replace("Engineering", "Science")
print(new_module_name)
# Out:
# Data Science
